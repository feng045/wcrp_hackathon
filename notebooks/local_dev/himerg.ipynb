# %%
import easygems.healpix as egh
import matplotlib as mpl
import xarray as xr

ds = xr.open_zarr('https://hackathon-o.s3-ext.jc.rl.ac.uk/sim-data/dev/v3/imerg/imerg.hp_z9.zarr')
# time in ['2019-08-01 00:00', '2020-08-31 00:00']
egh.healpix_show(ds.precipitation.sel(time='2019-08-01 00:00'), norm=mpl.colors.LogNorm(vmin=10e-2, vmax=30))

# %%
ds.time.values[[0, -1]]
# Out:
# array(['2019-08-01T00:00:00.000000000', '2020-09-01T00:00:00.000000000'],
#       dtype='datetime64[ns]')
