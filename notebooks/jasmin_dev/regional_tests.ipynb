# %%
import iris
import xarray as xr

# %%
path = '/gws/nopw/j04/kscale/DYAMOND3_example_data/sample_data_hirerarchy/10km-GAL9-nest/CTC_km4p4_RAL3P3/field.pp/apvera.pp/CTC_km4p4_RAL3P3.n1280_GAL9_nest.apvera_20200120T00.pp'
cubes = iris.load(path)
# Out:
# /home/users/mmuetz/miniforge3/envs/hackathon_env/lib/python3.12/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)

# %%
da = xr.DataArray.from_iris(cubes[2])
# Out:
# /tmp/ipykernel_2082/4008563845.py:1: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   da = xr.DataArray.from_iris(cubes[2])

# %%
da
# Out:
# <xarray.DataArray 'air_temperature' (time: 13, latitude: 1650, longitude: 9000)> Size: 772MB
# dask.array<filled, shape=(13, 1650, 9000), dtype=float32, chunksize=(1, 1650, 9000), chunktype=numpy.ndarray>
# Coordinates:
#   * time                     (time) datetime64[ns] 104B 2020-01-20T00:02:00 ....
#   * latitude                 (latitude) float32 7kB -39.98 -39.94 ... 25.98
#   * longitude                (longitude) float32 36kB 0.02 0.06 ... 359.9 360.0
#     forecast_reference_time  datetime64[ns] 8B ...
#     height                   float64 8B ...
#     forecast_period          (time) timedelta64[ns] 104B ...
# Attributes:
#     standard_name:  air_temperature
#     units:          K
#     source:         Data from Met Office Unified Model
#     um_version:     13.5
#     STASH:          m01s03i236

# %%
da.isel(time=0).plot()
# Out:
# /tmp/ipykernel_2082/1392607447.py:1: SerializationWarning: Can't decode floating point timedelta to 's' without precision loss, decoding to 'ns' instead. To silence this warning use time_unit='ns' in call to decoding function.
#   da.isel(time=0).plot()

# %%
da.shape[1] * da.shape[2]
# Out:
# 14850000

# %%
int(2560**2 * 2 * 1.5)
# Out:
# 19660800

# %%
path = '/gws/nopw/j04/kscale/DYAMOND3_example_data/sample_data_hirerarchy/10km-GAL9-nest/SAmer_km4p4_RAL3P3/field.pp/apvera.pp/SAmer_km4p4_RAL3P3.n1280_GAL9_nest.apvera_20200120T00.pp'
cubes = iris.load(path)
da = xr.DataArray.from_iris(cubes[2])
da.isel(time=0).plot()
# Out:
# /tmp/ipykernel_2082/2750118219.py:3: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   da = xr.DataArray.from_iris(cubes[2])
# /tmp/ipykernel_2082/2750118219.py:4: SerializationWarning: Can't decode floating point timedelta to 's' without precision loss, decoding to 'ns' instead. To silence this warning use time_unit='ns' in call to decoding function.
#   da.isel(time=0).plot()

# %%
path = '/gws/nopw/j04/kscale/DYAMOND3_example_data/sample_data_hirerarchy/10km-GAL9-nest/SEA_km4p4_RAL3P3/field.pp/apvera.pp/SEA_km4p4_RAL3P3.n1280_GAL9_nest.apvera_20200120T00.pp'
cubes = iris.load(path)
da = xr.DataArray.from_iris(cubes[2])
da.isel(time=0).plot()
# Out:
# /tmp/ipykernel_2082/895104353.py:3: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   da = xr.DataArray.from_iris(cubes[2])
# /tmp/ipykernel_2082/895104353.py:4: SerializationWarning: Can't decode floating point timedelta to 's' without precision loss, decoding to 'ns' instead. To silence this warning use time_unit='ns' in call to decoding function.
#   da.isel(time=0).plot()

# %%
path = '/gws/nopw/j04/kscale/DYAMOND3_example_data/sample_data_hirerarchy/10km-GAL9-nest/Africa_km4p4_RAL3P3/field.pp/apvera.pp/Africa_km4p4_RAL3P3.n1280_GAL9_nest.apvera_20200120T00.pp'
cubes = iris.load(path)
da = xr.DataArray.from_iris(cubes[2])
da.isel(time=0).plot()
# Out:
# /tmp/ipykernel_2082/1032664529.py:3: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   da = xr.DataArray.from_iris(cubes[2])
# /tmp/ipykernel_2082/1032664529.py:4: SerializationWarning: Can't decode floating point timedelta to 's' without precision loss, decoding to 'ns' instead. To silence this warning use time_unit='ns' in call to decoding function.
#   da.isel(time=0).plot()
