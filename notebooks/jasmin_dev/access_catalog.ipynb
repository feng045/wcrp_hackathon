# %%
import pystac

cat = pystac.Catalog.from_file('https://api.stac.ceda.ac.uk/')
dy3 = cat.get_child('DYAMOND3_N2560')
# How do I get hold of the next level of data (assets I think)?

# %%
list(dy3.get_all_items())
# Out:
# []

# %%
dy3.get_links()
# Out:
# [<Link rel=aggregate target=https://api.stac.ceda.ac.uk/collections/DYAMOND3_N2560/aggregate>,
#  <Link rel=aggregations target=https://api.stac.ceda.ac.uk/collections/DYAMOND3_N2560/aggregations>,
#  <Link rel=items target=https://api.stac.ceda.ac.uk/collections/DYAMOND3_N2560/items>,
#  <Link rel=queryables target=https://api.stac.ceda.ac.uk/collections/DYAMOND3_N2560/queryables>,
#  <Link rel=root target=<Catalog id=stac-fastapi>>,
#  <Link rel=string target=https://api.stac.ceda.ac.uk/string>,
#  <Link rel=self target=https://api.stac.ceda.ac.uk/collections/DYAMOND3_N2560>,
#  <Link rel=parent target=<Catalog id=stac-fastapi>>]

# %%
import pystac_client
client = pystac_client.Client.open(url='https://api.stac.ceda.ac.uk/')
search = client.search(collections=['DYAMOND3_N2560'])
for it in search.items():
     print(it.id)
# Out:
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z9.earth2grid
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z9
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z8.earth2grid
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z8
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z7.earth2grid
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z7
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z6.earth2grid
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z6
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z5.earth2grid
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z5
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z4.earth2grid
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z4
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z3.earth2grid
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z3
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z2.earth2grid
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z2
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z10.earth2grid
# DYAMOND3_example_data_5km-RAL3_2d_data.2d.z10
# ...

# %%
it
# Out:
# <Item id=DYAMOND3_example_data_5km-RAL3_2d_data.2d.z0>

# %%
asset = it.assets['zstore']

# %%
asset
# Out:
# <Asset href=http://hackathon-o.s3.jc.rl.ac.uk/sim-data/DYAMOND3_example_data/5km-RAL3/2d/data.2d.z0.zarr/>

# %%
asset.href
# Out:
# 'http://hackathon-o.s3.jc.rl.ac.uk/sim-data/DYAMOND3_example_data/5km-RAL3/2d/data.2d.z0.zarr/'
