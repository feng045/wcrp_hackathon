# %%
import intake
ds = intake.open_stac_item(
    "https://eerie.cloud.dkrz.de/datasets/ifs-amip-tco1279.hist.v20240901.atmos.gr025.2D_24h/stac"
).data.to_dask()
# Out:
# /home/users/mmuetz/miniforge3/envs/hackathon_env/lib/python3.12/site-packages/intake_xarray/base.py:21: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   'dims': dict(self._ds.dims),

# %%
ds.time.values[[0, 1, -1]]
# Out:
# array(['1980-01-01T12:00:00.000000000', '1980-01-02T12:00:00.000000000',
#        '2023-12-31T12:00:00.000000000'], dtype='datetime64[ns]')

# %%
ds

# %%
import xarray as xr

# %%
ds2 = xr.open_dataset('https://eerie.cloud.dkrz.de/datasets/ifs-amip-tco1279.hist.v20240901.atmos.gr025.2D_24h/zarr', engine='zarr')

# %%
ds2
# Out:
# <xarray.Dataset> Size: 3TB
# Dimensions:       (time: 16071, value: 1038240)
# Coordinates:
#     lat           (value) float64 8MB ...
#     lon           (value) float64 8MB ...
#   * time          (time) datetime64[ns] 129kB 1980-01-01T12:00:00 ... 2023-12...
# Dimensions without coordinates: value
# Data variables: (12/21)
#     10fg          (time, value) float64 133GB ...
#     avg_10u       (time, value) float64 133GB ...
#     avg_10v       (time, value) float64 133GB ...
#     avg_2sh       (time, value) float64 133GB ...
#     avg_ci        (time, value) float64 133GB ...
#     avg_lcc_frac  (time, value) float64 133GB ...
#     ...            ...
#     msnlwrf       (time, value) float64 133GB ...
#     msnswrf       (time, value) float64 133GB ...
#     msshf         (time, value) float64 133GB ...
#     mtnlwrf       (time, value) float64 133GB ...
#     mtnswrf       (time, value) float64 133GB ...
#     tprate        (time, value) float64 133GB ...
# ...
